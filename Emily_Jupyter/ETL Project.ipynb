# %% [markdown]
# ## ETL Project

# %%
# Import dependencies
import pandas as pd
import datetime as dt
import requests
import json

# %% [markdown]
# ## Source 2:  Spaceflight News
# Website:  https://spaceflightnewsapi.net

# %%
# URL for GET requests to retrieve vehicle data
url = "https://spaceflightnewsapi.net/api/v1/articles"

# %%
# Pretty print JSON for all articles
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "docs": [
#         {
#             "__v": 1,
#             "_id": "5f4a369bb19b5c530b77323f",
#             "categories": [],
#             "date_added": 1598699163,
#             "date_published": 1598699160,
#             "events": [],
#             "featured": true,
#             "featured_image": "https://mk0spaceflightnoa02a.kinstacdn.com/wp-content/uploads/2015/01/f9landing_feature-326x245.png",
#             "id": "",
#             "imported_date": "2020-08-29T11:06:03.000Z",
#             "launches": [],
#             "ll": [],
#             "news_site": "spaceflightnow",
#             "news_site_long": "Spaceflight Now",
#             "published_date": "2020-08-29T11:06:00.000Z",
#             "tags": [
#                 "falcon",
#                 "pad",
#                 "launch",
#                 "delayed",
#                 "delta",
#                 "cape",
#                 "4heavy",
#                 "spy",
#                 "saocom",
#                 "1b",
#                 "satellite",
#                 "nro",
#                 "rocket",
#                 "spaceflight",
#                 "week",
#                 "engines"
#             ],
#             "title": "Launch of NRO spy satellite delayed at least a week",
#             "url": "https://spaceflightnow.com/2020/08/29/launch-of-nro-spy-satellite-delayed-at-least-a-week/"
#         },
#         {
#             "_id": "5f4a2639b19b5c530b64eb24",
#             "categories": [],
#             "date_added": 1598502949,
#             "date_published": 1598694557,
#             "events": [],
#             "featured": false,
#             "featured_image": "https://spacenews.com/wp-content/uploads/2020/08/Screen-Shot-2020-08-29-at-3.30.01-AM-879x485.png",
#             "id": "",
#             "imported_date": "2020-08-27T04:35:49.598Z",
#             "launches": [],
#             "ll": [],
#             "news_site": "spacenews",
#             "news_site_long": "SpaceNews",
#             "published_date": "2020-08-29T09:49:17.000Z",
#             "tags": [
#                 "NRO",
#                 "Delta 4",
#                 "ULA"
#             ],
#             "title": "ULA launch of NRO satellite on hold after Delta 4 Heavy hot fire abort",
#             "url": "https://spacenews.com/ula-launch-of-nro-satellite-on-hold-after-delta-4-heavy-hot-fire-abort/"
#         },
#         {
#             "_id": "5f46a9efb19b5c530b489d32",
#             "categories": [
#                 "commercial",
#                 "featured",
#                 "other",
#                 "uncrewed"
#             ],
#             "date_added": 1598687154,
#             "date_published": 1598687154,
#             "events": [],
#             "featured": false,
#             "featured_image": "https://www.nasaspaceflight.com/wp-content/uploads/2020/08/PSX_20200829_033551.jpg",
#             "id": 69597,
#             "imported_date": "2020-08-29T07:45:54.000Z",
#             "launches": [],
#             "ll": [],
#             "news_site": "nasaspaceflight",
#             "news_site_long": "NASA Spaceflight",
#             "published_date": "2020-08-29T07:45:54.000Z",
#             "tags": [
#                 "delta iv heavy",
#                 "nro",
#                 "nrol-44",
#                 "ula"
#             ],
#             "title": "ULA scrubs NROL-44 mission due to Delta IV Heavy abort at T-3 seconds",
#             "url": "https://www.nasaspaceflight.com/2020/08/ula-nrol-44-delta-iv-heavy/"
#         },
#         {
#             "_id": "5f49d8feb19b5c530b2bc216",
#             "categories": [],
#             "date_added": 1598675198,
#             "date_published": 1598675078,
#             "events": [],
#             "featured": false,
#             "featured_image": "https://www.teslarati.com/wp-content/uploads/2020/08/Banner1.jpg",
#             "id": "",
#             "imported_date": "2020-08-29T04:26:38.000Z",
#             "launches": [],
#             "ll": [],
#             "news_site": "teslarati",
#             "news_site_long": "Teslarati",
#             "published_date": "2020-08-29T04:24:38.000Z",
#             "tags": [
#                 "lab",
#                 "launch",
#                 "launches",
#                 "heavy",
#                 "mission",
#                 "weather",
#                 "flight",
#                 "spacex",
#                 "rocket",
#                 "ula",
#                 "weekend",
#                 "attempt",
#                 "planned"
#             ],
#             "title": "SpaceX, Rocket Lab, ULA all have rocket launches planned this weekend",
#             "url": "https://www.teslarati.com/spacex-rocket-lab-ula-all-have-rocket-launches-planned-this-weekend/"
#         },
#         {
#             "_id": "5f4963a8b19b5c530bc6d04a",
#             "categories": [
#                 "other"
#             ],
#             "date_added": 1598645156,
#             "date_published": 1598645156,
#             "events": [],
#             "featured": false,
#             "featured_image": "https://www.nasaspaceflight.com/wp-content/uploads/2020/08/CME.jpg",
#             "id": 69678,
#             "imported_date": "2020-08-28T20:05:56.000Z",
#             "launches": [],
#             "ll": [],
#             "news_site": "nasaspaceflight",
#             "news_site_long": "NASA Spaceflight",
#             "published_date": "2020-08-28T20:05:56.000Z",
#             "tags": [
#                 "esa",
#                 "heliophysics",
#                 "nasa",
#                 "parker solar probe",
#                 "sdo",
#                 "soho",
#                 "solar orbiter",
#                 "steero",
#                 "sun"
#             ],
#             "title": "Carrington Event still provides warning of Sun\u2019s potential 161 years later",
#             "url": "https://www.nasaspaceflight.com/2020/08/carrington-event-warning/"
#         },
#         {
#             "_id": "5f49615fb19b5c530bc3e90c",
#             "categories": [],
#             "date_added": 1598502949,
#             "date_published": 1598644091,
#             "events": [],
#             "featured": false,
#             "featured_image": "https://spacenews.com/wp-content/uploads/2019/12/starliner-orbit-879x485.jpg",
#             "id": "",
#             "imported_date": "2020-08-27T04:35:49.598Z",
#             "launches": [],
#             "ll": [],
#             "news_site": "spacenews",
#             "news_site_long": "SpaceNews",
#             "published_date": "2020-08-28T19:48:11.000Z",
#             "tags": [
#                 "NASA",
#                 "CST-100",
#                 "Commercial Crew"
#             ],
#             "title": "NASA and Boeing outline schedule of Starliner test flights",
#             "url": "https://spacenews.com/nasa-and-boeing-outline-schedule-of-starliner-test-flights/"
#         },
#         {
#             "_id": "5f494e9eb19b5c530bb2a77e",
#             "categories": [],
#             "date_added": 1598502949,
#             "date_published": 1598638982,
#             "events": [],
#             "featured": false,
#             "featured_image": "https://spacenews.com/wp-content/uploads/2020/05/Lockheed-Martin-built-Next-Gen-OPIR-GEO-Space-Vehicle-879x485.jpg",
#             "id": "",
#             "imported_date": "2020-08-27T04:35:49.598Z",
#             "launches": [],
#             "ll": [],
#             "news_site": "spacenews",
#             "news_site_long": "SpaceNews",
#             "published_date": "2020-08-28T18:23:02.000Z",
#             "tags": [
#                 "Next-Gen OPIR",
#                 "SMC",
#                 "Acquisitions"
#             ],
#             "title": "Space Force buyers want a classified cloud to manage satellite programs",
#             "url": "https://spacenews.com/space-force-buyers-want-a-classified-cloud-to-manage-satellite-programs/"
#         },
#         {
#             "_id": "5f496853b19b5c530bcc73af",
#             "categories": [],
#             "date_added": 1598646355,
#             "date_published": 1598637540,
#             "events": [],
#             "featured": false,
#             "featured_image": "https://www.nasa.gov/sites/default/files/styles/1x1_cardfeed/public/thumbnails/image/sep_activeregionview_v01160_print.jpg?itok=taplpfbn",
#             "id": "",
#             "imported_date": "2020-08-28T20:25:55.000Z",
#             "launches": [],
#             "ll": [],
#             "news_site": "nasa",
#             "news_site_long": "NASA",
#             "published_date": "2020-08-28T17:59:00.000Z",
#             "tags": [
#                 "nasa",
#                 "selects",
#                 "proposals",
#                 "new",
#                 "space",
#                 "environment",
#                 "missions"
#             ],
#             "title": "NASA Selects Proposals for New Space Environment Missions",
#             "url": "https://www.nasa.gov/press-release/nasa-selects-proposals-for-new-space-environment-missions"
#         },
#         {
#             "_id": "5f493979b19b5c530ba158e2",
#             "categories": [],
#             "date_added": 1598634361,
#             "date_published": 1598634360,
#             "events": [],
#             "featured": false,
#             "featured_image": "https://mk0spaceflightnoa02a.kinstacdn.com/wp-content/uploads/2020/08/50273409757_4353ebe9ed_6k.jpg",
#             "id": "",
#             "imported_date": "2020-08-28T17:06:01.000Z",
#             "launches": [],
#             "ll": [],
#             "news_site": "spaceflightnow",
#             "news_site_long": "Spaceflight Now",
#             "published_date": "2020-08-28T17:06:00.000Z",
#             "tags": [
#                 "falcon",
#                 "cape",
#                 "launch",
#                 "space",
#                 "launches",
#                 "weekend",
#                 "weather",
#                 "saocom",
#                 "canaveral",
#                 "spacex",
#                 "rocket",
#                 "spaceflight",
#                 "planned"
#             ],
#             "title": "Up to three launches planned this weekend from Cape Canaveral",
#             "url": "https://spaceflightnow.com/2020/08/28/up-to-three-launches-planned-this-weekend-from-cape-canaveral/"
#         },
#         {
#             "_id": "5f491d61b19b5c530b7d977a",
#             "categories": [],
#             "date_added": 1598502949,
#             "date_published": 1598626638,
#             "events": [],
#             "featured": false,
#             "featured_image": "https://spacenews.com/wp-content/uploads/2020/08/Thuraya-4-NGS-Earth-View-879x485.jpeg",
#             "id": "",
#             "imported_date": "2020-08-27T04:35:49.598Z",
#             "launches": [],
#             "ll": [],
#             "news_site": "spacenews",
#             "news_site_long": "SpaceNews",
#             "published_date": "2020-08-28T14:57:18.000Z",
#             "tags": [
#                 "Yahsat",
#                 "Airbus Defence and Space",
#                 "Thuraya"
#             ],
#             "title": "Yahsat begins Thuraya fleet refresh with Airbus satellite order",
#             "url": "https://spacenews.com/yahsat-begins-thuraya-fleet-refresh-with-airbus-satellite-order/"
#         }
#     ],
#     "hasNextPage": true,
#     "hasPrevPage": false,
#     "limit": 10,
#     "nextPage": 2,
#     "page": 1,
#     "pagingCounter": 1,
#     "prevPage": null,
#     "totalDocs": 6566,
#     "totalPages": 657
# }
