# %% [markdown]
# ## ETL Project
# * Data Source 2 - JSON
# * Source :  News
# * Website:  https://www.huffpost.com/

# %% [markdown]
# ## Extract

# %%
# Import dependencies
import pandas as pd
import datetime as dt
import numpy as np

# %%
# Read json file into pandas
file = "../Resources/News_Category_Dataset_v2.json"
df = pd.read_json(file, lines=True)
df
# Out:
#              category                                           headline  \
# 0               CRIME  There Were 2 Mass Shootings In Texas Last Week...
# 1       ENTERTAINMENT  Will Smith Joins Diplo And Nicky Jam For The 2...
# 2       ENTERTAINMENT    Hugh Grant Marries For The First Time At Age 57
# 3       ENTERTAINMENT  Jim Carrey Blasts 'Castrato' Adam Schiff And D...
# 4       ENTERTAINMENT  Julianna Margulies Uses Donald Trump Poop Bags...
# ...               ...                                                ...
# 200848           TECH  RIM CEO Thorsten Heins' 'Significant' Plans Fo...
# 200849         SPORTS  Maria Sharapova Stunned By Victoria Azarenka I...
# 200850         SPORTS  Giants Over Patriots, Jets Over Colts Among  M...
# 200851         SPORTS  Aldon Smith Arrested: 49ers Linebacker Busted ...
# 200852         SPORTS  Dwight Howard Rips Teammates After Magic Loss ...
#
#                  authors                                               link  \
# ...

# %% [markdown]
# ## Transform

# %%
# substring to be searched 
sub ='SpaceX'
  
# creating and passsing series to new column 
df["Indexes"]= df["headline"].str.find(sub) 
  
# display 
df
# Out:
#              category                                           headline  \
# 0               CRIME  There Were 2 Mass Shootings In Texas Last Week...
# 1       ENTERTAINMENT  Will Smith Joins Diplo And Nicky Jam For The 2...
# 2       ENTERTAINMENT    Hugh Grant Marries For The First Time At Age 57
# 3       ENTERTAINMENT  Jim Carrey Blasts 'Castrato' Adam Schiff And D...
# 4       ENTERTAINMENT  Julianna Margulies Uses Donald Trump Poop Bags...
# ...               ...                                                ...
# 200848           TECH  RIM CEO Thorsten Heins' 'Significant' Plans Fo...
# 200849         SPORTS  Maria Sharapova Stunned By Victoria Azarenka I...
# 200850         SPORTS  Giants Over Patriots, Jets Over Colts Among  M...
# 200851         SPORTS  Aldon Smith Arrested: 49ers Linebacker Busted ...
# 200852         SPORTS  Dwight Howard Rips Teammates After Magic Loss ...
#
#                  authors                                               link  \
# ...

# %%
df['Indexes'].value_counts()
# Out:
# -1     200829
#  0         17
#  25         1
#  23         1
#  19         1
#  13         1
#  12         1
#  11         1
#  4          1
# Name: Indexes, dtype: int64

# %%
df = df[df.Indexes != -1]
df
# Out:
#         category                                           headline  \
# 1958     SCIENCE  SpaceX Rocket Blasts Off Carrying NASA's New P...
# 3407        TECH  Elon Musk Pulls Tesla, SpaceX Facebook Pages I...
# 24864    SCIENCE  SpaceX Launches Its First Recycled Cargo Ship ...
# 30597       TECH  SpaceX Launches And Lands The First Recycled O...
# 33292    SCIENCE  SpaceX To Send Two Private Citizens Around The...
# 33958    SCIENCE  SpaceX Launches Rocket From NASA Pad In Florid...
# 35082   BUSINESS  Elon Musk's Tesla, SpaceX Join Companies Oppos...
# 37237    SCIENCE  SpaceX Launches First Rocket Since Explosion, ...
# 42301   BUSINESS  SpaceX Executive Quits To Fight Trump As A Gra...
# 46155    SCIENCE  Elon Musk's SpaceX Has Company In The Race To ...
# 48309    SCIENCE  Elon Musk: SpaceX Launch Explosion Is 'Most Di...
# 49084       TECH  Explosion At SpaceX Launch Site At Cape Canave...
# 49092    SCIENCE  Watch A Video Of Today's SpaceX Falcon 9 Rocke...
# ...

# %%
# Save df to csv file
df.to_csv('../Resources/News_Reports.csv', index=False)

# %%
# Sort by date range
bins = [np.datetime64(date(2012,1,1)),np.datetime64(date(2013,1,1)),np.datetime64(date(2014,1,1)), np.datetime64(date(2015,1,1)), np.datetime64(date(2016,1,1)),np.datetime64(date(2017,1,1)),np.datetime64(date(2018,1,1)),np.datetime64(date(2019,1,1)),np.datetime64(date(2020,1,1))]
group_names = ['2012','2013','2014', '2015', '2016', '2017', '2018', '2019']
#df['date'] = pd.to_datetime(df['date'])
df['date'] = pd.to_datetime(df['date'])
df['categories'] = pd.cut(df['date'], bins, labels=group_names)
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-e3bf5e47f2c5> in <module>
#       1 # Sort by date range
# ----> 2 bins = [np.datetime64(date(2012,1,1)),np.datetime64(date(2013,1,1)),np.datetime64(date(2014,1,1)), np.datetime64(date(2015,1,1)), np.datetime64(date(2016,1,1)),np.datetime64(date(2017,1,1)),np.datetime64(date(2018,1,1)),np.datetime64(date(2019,1,1)),np.datetime64(date(2020,1,1))]
#       3 group_names = ['2012','2013','2014', '2015', '2016', '2017', '2018', '2019']
#       4 #df['date'] = pd.to_datetime(df['date'])
#       5 df['date'] = pd.to_datetime(df['date'])
#
# NameError: name 'date' is not defined

# %%
df['categories'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'categories'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-d819ca681dbb> in <module>
# ...

# %%
df.to_csv('News_Reports_only_SpaceX_wi.csv', index=False)

# %% [markdown]
# ## Merge dataframes

# %%
# #Open SpaceX_df
#spacex_file = "../Resources/SpaceX_info.csv"
#spacex_df = pd.read_csv(spacex_file)
#spacex_df

# %%
#merged_df = pd.concat([df, spacex_df])
#merged_df

# %%
# Save as sql
#merged_df.to_sql(name="SpaceX", con=engine)

# %%
# The default port used by MongoDB is 27017
# https://docs.mongodb.com/manual/reference/default-mongodb-port/
#conn = 'mongodb://localhost:27017'
#client = pymongo.MongoClient(conn)

# Declare the database
#db = client.spacex_db

# Declare the collection
#spacex = db.spacex_db

# %%
# Insert the document into the database
# The database and collection, if they don't already exist, will be created at this point.
#spacex.insert_one(news)

# %% [markdown]
# ## Load

# %%
from sqlalchemy import create_engine

# %%
# Connect to local database
rds_connection_string = "postgres:postgres@localhost:5432/spacex_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
df.to_sql(name = "space_x", con = engine, if_exists = "append", index = False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2337         try:
# -> 2338             return fn()
#    2339         except dialect.dbapi.Error as e:
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
# ...
